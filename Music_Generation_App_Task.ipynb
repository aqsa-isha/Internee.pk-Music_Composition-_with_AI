# %% [markdown]
# <a href="https://colab.research.google.com/github/aqsa-isha/Internee.pk-Music_Composition-_with_AI/blob/main/Music_Generation_App_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/facebookresearch/audiocraft
# Out:
# fatal: destination path 'audiocraft' already exists and is not an empty directory.

# %%
# %cd audiocraft
# Out:
# /content/audiocraft

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/audiocraft
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: audiocraft
#     Found existing installation: audiocraft 1.4.0a1
#     Uninstalling audiocraft-1.4.0a1:
#       Successfully uninstalled audiocraft-1.4.0a1
#   Running setup.py develop for audiocraft
# ...

# %%
# !pip install streamlit torch torchaudio audiocraft
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 83.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 105.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 7.0 MB/s eta 0:00:00
# ...

# %%
# !pip install pyngrok
from pyngrok import ngrok

# %%
import subprocess
from pyngrok import ngrok
import time
import os

# Ensure ngrok is authenticated
ngrok.set_auth_token("2pr8TVJ1Yw24rivNIUoTk1wGYuo_6H4E6iiAYhtPx2ib4BxjB")

# Define the path to your Streamlit app
streamlit_app_path = "/content/app.py"  # Update this path if necessary

try:
    # Start the Streamlit app
    print("Starting Streamlit app...")
    process = subprocess.Popen(["streamlit", "run", streamlit_app_path])

    # Wait for Streamlit to initialize
    time.sleep(10)  # Adjust this value or implement a check for server readiness

    # Start the ngrok tunnel for the default Streamlit port (8501)
    print("Starting ngrok tunnel...")
    public_url = ngrok.connect(8501)
    print(f"Access your app at: {public_url}")

    # Keep the script running to maintain the tunnel
    while True:
        time.sleep(1)

except Exception as e:
    print(f"An error occurred: {e}")

finally:
    # Ensure subprocess and ngrok are terminated on script exit
    print("Stopping services...")
    process.terminate()
    ngrok.kill()
# Out:
# Starting Streamlit app...
# Starting ngrok tunnel...
# Access your app at: NgrokTunnel: "https://575b-34-125-184-139.ngrok-free.app" -> "http://localhost:8501"
